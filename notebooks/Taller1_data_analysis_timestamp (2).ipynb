# %% [markdown]
# # **Taller 1**
# ### **Integrantes:**
# * Diego Felipe Carvajal Lombo (201911910)
# * Brenda Catalina Barahona Pinilla (201812721)
# * Sergio Julian Zona Moreno (201914936)

# %%
# Posible instalación necesaria
# !conda install -c conda-forge scikit-surprise
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.

# %% [markdown]
# # **Carga y muestreo de los datos**

# %%
# Importación de librerias
seed = 161
import pandas as pd
import numpy as np
import hashlib

# Se importa la librería de tiempo para medir cuánto se demora en encontrar los hiperparámetros con cada modelo.
import time
import math

# Librerias CUDA
# import cudf
# cudf.set_option("spill", True)

# Database
import sqlite3

# Gráficos
import matplotlib.pyplot as plt

# Importamos la librería del SR
import os
from surprise import Reader
from surprise import Dataset
from surprise.model_selection import train_test_split
from surprise import KNNBasic, KNNWithZScore
from surprise import accuracy

#Para garantizar reproducibilidad en resultados
import random
seed = 2023
#random.seed(seed)
#np.random.seed(seed)

# Importar/Exportar modelos
from joblib import dump, load

# %%
# !nvidia-smi
# Out:
# Thu Mar  9 17:32:46 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 528.24       Driver Version: 528.24       CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:01:00.0 Off |                  N/A |
# | N/A   37C    P8    N/A /  N/A |      0MiB /  4096MiB |      1%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # **Carga de datos**

# %%
# Se cargan el conjunto total de los datos. 
# Leer TSV: https://stackoverflow.com/questions/9652832/how-to-load-a-tsv-file-into-a-pandas-dataframe
# Tokenizing data error: https://stackoverflow.com/questions/18039057/python-pandas-error-tokenizing-data

fields = ["userid", "timestamp", "musicbrainz-artist-id", "artist-name", "musicbrainz-track-id", "track-name"]

df_data=pd.read_csv('../data/userid-timestamp-artid-artname-traid-traname.tsv', sep='\t',
                     on_bad_lines='skip', skipinitialspace=True, names=fields)

# %%
# import cudf
# cudf.set_option("spill", True)
# df_data = cudf.from_pandas(df_data)

# %%
# Cantidad de datos y número de variables
df_data.shape
# Out:
# (19098853, 6)

# %%
# Ejemplo de muestra de los datos.
df_data.tail(5)
# Out:
#                userid             timestamp  \
# 19098848  user_001000  2008-01-27T22:02:35Z
# 19098849  user_001000  2008-01-27T21:56:52Z
# 19098850  user_001000  2008-01-27T21:52:36Z
# 19098851  user_001000  2008-01-27T21:49:12Z
# 19098852  user_001000  2008-01-27T21:43:14Z
#
#                          musicbrainz-artist-id artist-name  \
# 19098848  9e53f84d-ef44-4c16-9677-5fd4d78cbd7d       Wilco
# 19098849  9e53f84d-ef44-4c16-9677-5fd4d78cbd7d       Wilco
# 19098850  9e53f84d-ef44-4c16-9677-5fd4d78cbd7d       Wilco
# 19098851  9e53f84d-ef44-4c16-9677-5fd4d78cbd7d       Wilco
# 19098852  9e53f84d-ef44-4c16-9677-5fd4d78cbd7d       Wilco
#
#                           musicbrainz-track-id                 track-name
# 19098848  a490cabc-1e5c-4807-86c7-740c31a50009  Please Be Patient With Me
# 19098849  3e92e447-9e1f-440d-bc00-6734469880c5               Shake It Off
# 19098850  93d044e6-1bbb-46a6-ac8e-283382a89e6f        Side With The Seeds
# 19098851  5ac4386f-6146-4389-a762-4b43f362d2c8               Sky Blue Sky
# 19098852  3acc99bc-a349-420f-ad28-7095eb3533c9         Impossible Germany

# %%
# Tipos de las variables al cargar, todas son objetos.
df_data.dtypes
# Out:
# userid                   object
# timestamp                object
# musicbrainz-artist-id    object
# artist-name              object
# musicbrainz-track-id     object
# track-name               object
# dtype: object

# %%
# Número de valores nulos en filas.
df_plot = df_data.isnull().sum().sort_values()
df_plot
# Out:
# userid                         0
# timestamp                      0
# artist-name                    0
# track-name                    12
# musicbrainz-artist-id     600848
# musicbrainz-track-id     2162719
# dtype: int64

# %%
# Existen múltiples filas con valores nulos. Esto se debe a que son llaves foráneas.
#plt.barh(df_plot.index, df_plot.values)

# %% [markdown]
# # **Perfilamiento y entendimiento de los datos**
# Obtendremos estadísticas descriptivas pertinentes y posteriormente ingresaremos el conjunto de datos a Pandas Profiling para obtener un reporte adecuado de correlación e interacción entre variables.

# %%
# Obtención de estadísticas descriptivas.
df_data.describe()
# Out:
#              userid             timestamp  \
# count      19098853              19098853
# unique          992              17454730
# top     user_000949  2009-02-26T21:29:15Z
# freq         183103                   248
#
#                        musicbrainz-artist-id artist-name  \
# count                               18498005    19098853
# unique                                107295      173921
# top     a74b1b7f-71a5-4011-9441-d0b5e4122711   Radiohead
# freq                                  115099      115099
#
#                         musicbrainz-track-id track-name
# count                               16936134   19098841
# unique                                960402    1083471
# top     db16d0b3-b8ce-4aa8-a11a-e4d53cc7f8a6      Intro
# freq                                    3991      17561

# %%
# Obtención de estadísticas descriptivas.
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19098853 entries, 0 to 19098852
# Data columns (total 6 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   userid                 object
#  1   timestamp              object
#  2   musicbrainz-artist-id  object
#  3   artist-name            object
#  4   musicbrainz-track-id   object
#  5   track-name             object
# dtypes: object(6)
# memory usage: 874.3+ MB

# %%
df_data['timestamp'].describe()
# Out:
# count                 19098853
# unique                17454730
# top       2009-02-26T21:29:15Z
# freq                       248
# Name: timestamp, dtype: object

# %%
df_data['timestamp'].min()
# Out:
# '2005-02-14T00:00:07Z'

# %%
df_data['timestamp'].max()
# Out:
# '2013-09-29T18:32:04Z'

# %%
df_data['DateTime'] = pd.to_datetime(df_data['timestamp'])
df_data
# Out:
#                userid             timestamp  \
# 0         user_000001  2009-05-04T23:08:57Z
# 1         user_000001  2009-05-04T13:54:10Z
# 2         user_000001  2009-05-04T13:52:04Z
# 3         user_000001  2009-05-04T13:42:52Z
# 4         user_000001  2009-05-04T13:42:11Z
# ...               ...                   ...
# 19098848  user_001000  2008-01-27T22:02:35Z
# 19098849  user_001000  2008-01-27T21:56:52Z
# 19098850  user_001000  2008-01-27T21:52:36Z
# 19098851  user_001000  2008-01-27T21:49:12Z
# 19098852  user_001000  2008-01-27T21:43:14Z
#
#                          musicbrainz-artist-id artist-name  \
# 0         f1b1cf71-bd35-4e99-8624-24a6e15f133a   Deep Dish
# 1         a7f7df4a-77d8-4f12-8acd-5c60c93f4de8        坂本龍一
# 2         a7f7df4a-77d8-4f12-8acd-5c60c93f4de8        坂本龍一
# 3         a7f7df4a-77d8-4f12-8acd-5c60c93f4de8        坂本龍一
# 4         a7f7df4a-77d8-4f12-8acd-5c60c93f4de8        坂本龍一
# ...                                        ...         ...
# 19098848  9e53f84d-ef44-4c16-9677-5fd4d78cbd7d       Wilco
# 19098849  9e53f84d-ef44-4c16-9677-5fd4d78cbd7d       Wilco
# 19098850  9e53f84d-ef44-4c16-9677-5fd4d78cbd7d       Wilco
# 19098851  9e53f84d-ef44-4c16-9677-5fd4d78cbd7d       Wilco
# 19098852  9e53f84d-ef44-4c16-9677-5fd4d78cbd7d       Wilco
#
#                           musicbrainz-track-id  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ...                                        ...
# 19098848  a490cabc-1e5c-4807-86c7-740c31a50009
# 19098849  3e92e447-9e1f-440d-bc00-6734469880c5
# 19098850  93d044e6-1bbb-46a6-ac8e-283382a89e6f
# 19098851  5ac4386f-6146-4389-a762-4b43f362d2c8
# 19098852  3acc99bc-a349-420f-ad28-7095eb3533c9
#
#                                           track-name                  DateTime
# 0         Fuck Me Im Famous (Pacha Ibiza)-09-28-2007 2009-05-04 23:08:57+00:00
# 1                  Composition 0919 (Live_2009_4_15) 2009-05-04 13:54:10+00:00
# 2                               Mc2 (Live_2009_4_15) 2009-05-04 13:52:04+00:00
# 3                            Hibari (Live_2009_4_15) 2009-05-04 13:42:52+00:00
# 4                               Mc1 (Live_2009_4_15) 2009-05-04 13:42:11+00:00
# ...                                              ...                       ...
# 19098848                   Please Be Patient With Me 2008-01-27 22:02:35+00:00
# 19098849                                Shake It Off 2008-01-27 21:56:52+00:00
# 19098850                         Side With The Seeds 2008-01-27 21:52:36+00:00
# 19098851                                Sky Blue Sky 2008-01-27 21:49:12+00:00
# 19098852                          Impossible Germany 2008-01-27 21:43:14+00:00
#
# [19098853 rows x 7 columns]

# %%
df_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19098853 entries, 0 to 19098852
# Data columns (total 7 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   userid                 object
#  1   timestamp              object
#  2   musicbrainz-artist-id  object
#  3   artist-name            object
#  4   musicbrainz-track-id   object
#  5   track-name             object
#  6   DateTime               datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), object(6)
# memory usage: 1020.0+ MB

# %%
df_artist_track = df_data.loc[:, ['artist-name', 'track-name']].drop_duplicates()
df_artist_track
# Out:
#           artist-name                                  track-name
# 0           Deep Dish  Fuck Me Im Famous (Pacha Ibiza)-09-28-2007
# 1                坂本龍一           Composition 0919 (Live_2009_4_15)
# 2                坂本龍一                        Mc2 (Live_2009_4_15)
# 3                坂本龍一                     Hibari (Live_2009_4_15)
# 4                坂本龍一                        Mc1 (Live_2009_4_15)
# ...               ...                                         ...
# 19098595  Katrah-Quey         France Horns, Scanning, And Boombap
# 19098596  Katrah-Quey                       12 Years Of Readyness
# 19098597  Katrah-Quey                                     Neglect
# 19098599  Katrah-Quey                  An Orange Splash On Things
# 19098765     Dj Vadim                                    Friction
#
# [1498718 rows x 2 columns]

# %%
df_artist_track = df_artist_track.reset_index()
df_artist_track
# Out:
#             index  artist-name                                  track-name
# 0               0    Deep Dish  Fuck Me Im Famous (Pacha Ibiza)-09-28-2007
# 1               1         坂本龍一           Composition 0919 (Live_2009_4_15)
# 2               2         坂本龍一                        Mc2 (Live_2009_4_15)
# 3               3         坂本龍一                     Hibari (Live_2009_4_15)
# 4               4         坂本龍一                        Mc1 (Live_2009_4_15)
# ...           ...          ...                                         ...
# 1498713  19098595  Katrah-Quey         France Horns, Scanning, And Boombap
# 1498714  19098596  Katrah-Quey                       12 Years Of Readyness
# 1498715  19098597  Katrah-Quey                                     Neglect
# 1498716  19098599  Katrah-Quey                  An Orange Splash On Things
# 1498717  19098765     Dj Vadim                                    Friction
#
# [1498718 rows x 3 columns]

# %%
df_artist_track = df_artist_track.drop(['index'], axis=1)
df_artist_track
# Out:
#          artist-name                                  track-name
# 0          Deep Dish  Fuck Me Im Famous (Pacha Ibiza)-09-28-2007
# 1               坂本龍一           Composition 0919 (Live_2009_4_15)
# 2               坂本龍一                        Mc2 (Live_2009_4_15)
# 3               坂本龍一                     Hibari (Live_2009_4_15)
# 4               坂本龍一                        Mc1 (Live_2009_4_15)
# ...              ...                                         ...
# 1498713  Katrah-Quey         France Horns, Scanning, And Boombap
# 1498714  Katrah-Quey                       12 Years Of Readyness
# 1498715  Katrah-Quey                                     Neglect
# 1498716  Katrah-Quey                  An Orange Splash On Things
# 1498717     Dj Vadim                                    Friction
#
# [1498718 rows x 2 columns]

# %%
df_artist_track.rename(columns={"artist-name":"artist_name","track-name":"track_name"}, inplace=True)
df_artist_track
# Out:
#          artist_name                                  track_name
# id
# 0          Deep Dish  Fuck Me Im Famous (Pacha Ibiza)-09-28-2007
# 1               坂本龍一           Composition 0919 (Live_2009_4_15)
# 2               坂本龍一                        Mc2 (Live_2009_4_15)
# 3               坂本龍一                     Hibari (Live_2009_4_15)
# 4               坂本龍一                        Mc1 (Live_2009_4_15)
# ...              ...                                         ...
# 1498713  Katrah-Quey         France Horns, Scanning, And Boombap
# 1498714  Katrah-Quey                       12 Years Of Readyness
# 1498715  Katrah-Quey                                     Neglect
# 1498716  Katrah-Quey                  An Orange Splash On Things
# 1498717     Dj Vadim                                    Friction
#
# [1498718 rows x 2 columns]

# %%
# Contamos el número de veces que una persona escuchó una canción. Y tomamos esto como matriz de utilidad.
# La segunda línea quita el multi-index.
df_user_track = df_data.groupby(['userid', 'track-name']).count().sort_values('timestamp', ascending=False)['timestamp'].to_frame()
df_user_track = df_user_track.reset_index(level=[0,1])

# Optimizamos la memoria.
# Link: https://towardsdatascience.com/memory-efficient-data-science-types-53423d48ba1d
df_user_track['timestamp'] = df_user_track['timestamp'].astype(np.uint16)
df_user_track.rename(columns={"userid":"user_id","track-name":"track_name","timestamp": "rating"}, inplace=True)
df_user_track
# Out:
#              user_id                              track_name  rating
# 0        user_000008                               Heartless    2119
# 1        user_000008                See You In My Nightmares    2069
# 2        user_000008                            Say You Will    2065
# 3        user_000008                           Love Lockdown    2059
# 4        user_000008  Welcome To Heartbreak (Feat. Kid Cudi)    2059
# ...              ...                                     ...     ...
# 4407905  user_000593                 A Billion Tons Of Light       1
# 4407906  user_000152                                Muskogee       1
# 4407907  user_000593                         A Brighter Beat       1
# 4407908  user_000152                        Mun Täytyy Mennä       1
# 4407909  user_000515              The Theme Of The Anti-Hero       1
#
# [4407910 rows x 3 columns]

# %%
# from cuml.preprocessing import MinMaxScaler
from sklearn.preprocessing import MinMaxScaler
pd.options.mode.chained_assignment = None  # default='warn'

df_UT = df_user_track.copy()
# Devuelve las primeras 100 canciones con más reproducciones del usuario
# df_test = df_user_track.loc[(df_user_track['user_id'] == 'user_000008') | (df_user_track['user_id'] == 'user_000593')]
# usuarios = df_test['user_id'].unique()
usuarios = df_UT['user_id'].unique()
scaler = MinMaxScaler(feature_range=(1, 5))

for userId in usuarios:
    df_user = df_UT.loc[df_user_track['user_id'] == userId]
    df_UT.loc[df_UT['user_id'] == userId, 'rating'] = scaler.fit_transform(df_user[['rating']])
    
df_UT
# Out:
#              user_id                              track_name    rating
# 0        user_000008                               Heartless  5.000000
# 1        user_000008                See You In My Nightmares  4.905571
# 2        user_000008                            Say You Will  4.898017
# 3        user_000008                           Love Lockdown  4.886686
# 4        user_000008  Welcome To Heartbreak (Feat. Kid Cudi)  4.886686
# ...              ...                                     ...       ...
# 4407905  user_000593                 A Billion Tons Of Light  1.000000
# 4407906  user_000152                                Muskogee  1.000000
# 4407907  user_000593                         A Brighter Beat  1.000000
# 4407908  user_000152                        Mun Täytyy Mennä  1.000000
# 4407909  user_000515              The Theme Of The Anti-Hero  1.000000
#
# [4407910 rows x 3 columns]

# %%
df_UT.describe()
# Out:
#              rating
# count  4.407910e+06
# mean   1.141077e+00
# std    3.001056e-01
# min    1.000000e+00
# 25%    1.000000e+00
# 50%    1.023392e+00
# 75%    1.148148e+00
# max    5.000000e+00

# %%
# Contamos el número de veces que una persona escuchó un artista. Y tomamos esto como matriz de utilidad.
# La segunda línea quita el multi-index.
df_user_artist = df_data.groupby(['userid', 'artist-name']).count().sort_values('timestamp', ascending=False)['timestamp'].to_frame()
df_user_artist = df_user_artist.reset_index(level=[0,1])

# Optimizamos la memoria.
# Link: https://towardsdatascience.com/memory-efficient-data-science-types-53423d48ba1d
df_user_artist['timestamp'] = df_user_artist['timestamp'].astype(np.uint16)
df_user_artist.rename(columns={"userid":"user_id","artist-name":"artist_name","timestamp": "rating"}, inplace=True)
df_user_artist
# Out:
#             user_id              artist_name  rating
# 0       user_000008               Kanye West   26496
# 1       user_000141                Chemistry   25609
# 2       user_000499                The Knife   18597
# 3       user_000889                 Soilwork   15566
# 4       user_000084           Britney Spears   14614
# ...             ...                      ...     ...
# 897414  user_000593           Chris & Mollie       1
# 897415  user_000593   Celestial Aeon Project       1
# 897416  user_000593              Carla Bruni       1
# 897417  user_000082  Tymon & The Transistors       1
# 897418  user_000524                  Rumskib       1
#
# [897419 rows x 3 columns]

# %%
# Analizamos el consumo en memoria de los DF's
df_user_track.info()
print("------------------------------------------")
df_user_artist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4407910 entries, 0 to 4407909
# Data columns (total 3 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   user_id     object
#  1   track_name  object
#  2   rating      uint16
# dtypes: object(2), uint16(1)
# memory usage: 75.7+ MB
# ------------------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 897419 entries, 0 to 897418
# Data columns (total 3 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   user_id      897419 non-null  object
#  1   artist_name  897419 non-null  object
#  2   rating       897419 non-null  uint16
# dtypes: object(2), uint16(1)
# memory usage: 15.4+ MB

# %%
df_user_artist
# Out:
#             user_id              artist_name  rating
# 0       user_000008               Kanye West   26496
# 1       user_000141                Chemistry   25609
# 2       user_000499                The Knife   18597
# 3       user_000889                 Soilwork   15566
# 4       user_000084           Britney Spears   14614
# ...             ...                      ...     ...
# 897414  user_000593           Chris & Mollie       1
# 897415  user_000593   Celestial Aeon Project       1
# 897416  user_000593              Carla Bruni       1
# 897417  user_000082  Tymon & The Transistors       1
# 897418  user_000524                  Rumskib       1
#
# [897419 rows x 3 columns]

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import FunctionTransformer
from sklearn.compose import ColumnTransformer

# %%
from sklearn.preprocessing import MinMaxScaler
pd.options.mode.chained_assignment = None  # default='warn'

df_UA = df_user_artist.copy()
usuarios = df_UA['user_id'].unique()
scaler = MinMaxScaler(feature_range=(1, 5))

for userId in usuarios:
    df_user = df_UA.loc[df_user_artist['user_id'] == userId]
    df_UA.loc[df_UA['user_id'] == userId, 'rating'] = scaler.fit_transform(df_user[['rating']])
    
df_UA
# Out:
#             user_id              artist_name  rating
# 0       user_000008               Kanye West     5.0
# 1       user_000141                Chemistry     5.0
# 2       user_000499                The Knife     5.0
# 3       user_000889                 Soilwork     5.0
# 4       user_000084           Britney Spears     5.0
# ...             ...                      ...     ...
# 897414  user_000593           Chris & Mollie     1.0
# 897415  user_000593   Celestial Aeon Project     1.0
# 897416  user_000593              Carla Bruni     1.0
# 897417  user_000082  Tymon & The Transistors     1.0
# 897418  user_000524                  Rumskib     1.0
#
# [897419 rows x 3 columns]

# %%
user593 = df_user_artist.loc[df_user_artist['user_id'] == 'user_000593']
user593
# Out:
#             user_id             artist_name    rating
# 75      user_000593            Patrick Wolf  5.000000
# 314     user_000593               Pj Harvey  3.144476
# 371     user_000593               Radiohead  2.972616
# 498     user_000593            Jeff Buckley  2.711048
# 717     user_000593                    Urma  2.387158
# ...             ...                     ...       ...
# 897412  user_000593                Clayhill  1.000000
# 897413  user_000593   Christian Kjellvander  1.000000
# 897414  user_000593          Chris & Mollie  1.000000
# 897415  user_000593  Celestial Aeon Project  1.000000
# 897416  user_000593             Carla Bruni  1.000000
#
# [1069 rows x 3 columns]

# %%
# Exportamos los DF's
df_user_track.index.name='id'
df_user_track.to_csv("../data/processed/user_track.csv")
df_user_artist.index.name='id'
df_user_artist.to_csv("../data/processed/user_artist.csv")

df_UT.index.name='id'
df_UT.to_csv("../data/processed/user_track_rate.csv")
df_UA.index.name='id'
df_UA.to_csv("../data/processed/user_artist_rate.csv")

# %%
df_artist_track.index.name='id'
df_artist_track.to_csv("../data/processed/artist_track.csv")

# %%
# Este código genera la matriz de 1's y 0s. Realiza un pivote y cuenta las coincidencias.
#df_user_track = df_user_track.pivot(index='userid', columns='artist-name', values='timestamp')

# %%
# Se cargan el conjunto total de los datos. 
# Leer TSV: https://stackoverflow.com/questions/9652832/how-to-load-a-tsv-file-into-a-pandas-dataframe
# Tokenizing data error: https://stackoverflow.com/questions/18039057/python-pandas-error-tokenizing-data

df_users=pd.read_csv('../data/userid-profile.tsv', sep='\t')
df_users['registered'] = pd.to_datetime(df_users['registered']).apply(str)
df_users.rename(columns={"#id":"user_id"}, inplace=True)
df_users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 992 entries, 0 to 991
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   user_id     992 non-null    object
#  1   gender      884 non-null    object
#  2   age         286 non-null    float64
#  3   country     907 non-null    object
#  4   registered  992 non-null    object
# dtypes: float64(1), object(4)
# memory usage: 38.9+ KB

# %%
df_users
# Out:
#          user_id gender   age         country           registered
# 0    user_000001      m   NaN           Japan  2006-08-13 00:00:00
# 1    user_000002      f   NaN            Peru  2006-02-24 00:00:00
# 2    user_000003      m  22.0   United States  2005-10-30 00:00:00
# 3    user_000004      f   NaN             NaN  2006-04-26 00:00:00
# 4    user_000005      m   NaN        Bulgaria  2006-06-29 00:00:00
# ..           ...    ...   ...             ...                  ...
# 987  user_000996      f   NaN   United States  2006-07-17 00:00:00
# 988  user_000997      m   NaN   United States  2007-01-05 00:00:00
# 989  user_000998      m   NaN  United Kingdom  2005-09-28 00:00:00
# 990  user_000999      f   NaN          Poland  2007-07-24 00:00:00
# 991  user_001000      m   NaN   United States  2007-03-24 00:00:00
#
# [992 rows x 5 columns]

# %%
# Creamos la columna que tendrá el Password. Para facilitar nuestra simulación, esta columna será: hash256('user_id'+'123.')
def hash(x):
    h = hashlib.new('sha256')
    h.update(x.encode())
    return h.hexdigest()

df_users['password_hash'] = df_users['user_id'].apply(lambda x: hash(str(x)+'123.'))
df_users
# Out:
#          user_id gender   age         country           registered  \
# 0    user_000001      m   NaN           Japan  2006-08-13 00:00:00
# 1    user_000002      f   NaN            Peru  2006-02-24 00:00:00
# 2    user_000003      m  22.0   United States  2005-10-30 00:00:00
# 3    user_000004      f   NaN             NaN  2006-04-26 00:00:00
# 4    user_000005      m   NaN        Bulgaria  2006-06-29 00:00:00
# ..           ...    ...   ...             ...                  ...
# 987  user_000996      f   NaN   United States  2006-07-17 00:00:00
# 988  user_000997      m   NaN   United States  2007-01-05 00:00:00
# 989  user_000998      m   NaN  United Kingdom  2005-09-28 00:00:00
# 990  user_000999      f   NaN          Poland  2007-07-24 00:00:00
# 991  user_001000      m   NaN   United States  2007-03-24 00:00:00
#
#                                          password_hash
# 0    51e94ea69d81c394617371560c1aa022f5ecec92fbec6f...
# 1    ba40ebe35b562b6687252e5d1ab46f0501d32ee3ac2dd0...
# 2    05f4cdc5ac31f4b948045012dce4991d13790bb6087d40...
# 3    ff8cb1bbbd20a1c3cb1adce1d60dd64089ba963bc3e722...
# 4    f252ade4b897736f03a935891bb7621c53985df5d3315f...
# ..                                                 ...
# 987  948d27bea57b9c79890ae7ae5a2b59802f86a97199f909...
# 988  69f789605cc44a3d37192449ed68b39187bc48c91c05db...
# 989  721efa604cf85d874342335214bf2270b4c436b3be4793...
# 990  f2452fe018c883c56d8aace2939d30b5bdae3a6c0cdb1a...
# 991  62138e9ffb09d260723608b7817543e7583602a1bbcdc4...
#
# [992 rows x 6 columns]

# %%
df_users.to_csv("../data/processed/users.csv")

# %%
# Se genera un reporte de analítica. Demora menos de 1 minuto aproximadamente.
#profile = ProfileReport(df_user_artist.to_pandas(), title="Pandas Profiling Report", minimal=True)
#profile.to_file("reporte.html")

# %% [markdown]
# # **Creación de la base de datos SQLite3**
# Creamos una base de datos SQLite3, con base en los DF's generados.

# %%
# En caso de que no se pueda utilizar CUDF.
#df_user_track = df_user_track.to_pandas()
#df_user_artist = df_user_artist.to_pandas()

# %%
# Connect to the SQLite3 database
conn = sqlite3.connect('../backend/data/data.db')

# Create a cursor object
cur = conn.cursor()

# Create a new table in the database
cur.execute('CREATE TABLE IF NOT EXISTS user_track (id INTEGER PRIMARY KEY, user_id TEXT, track_name TEXT, rating INTEGER)')

for index, row in df_user_track.iterrows():
    cur.execute('INSERT INTO user_track (id, user_id, track_name, rating) VALUES (?, ?, ?, ?)', 
                (index, row['user_id'], row['track_name'], row['rating']))

# Commit the changes and close the database connection
conn.commit()
cur.close()
conn.close()

# %%
# Connect to the SQLite3 database
conn = sqlite3.connect('../backend/data/data.db')

# Create a cursor object
cur = conn.cursor()

# Create a new table in the database
cur.execute('CREATE TABLE IF NOT EXISTS user_artist (id INTEGER PRIMARY KEY, user_id TEXT, artist_name TEXT, rating INTEGER)')

for index, row in df_user_artist.iterrows():
    cur.execute('INSERT INTO user_artist (id, user_id, artist_name, rating) VALUES (?, ?, ?, ?)', 
                (index, row['user_id'], row['artist_name'], row['rating']))

# Commit the changes and close the database connection
conn.commit()
cur.close()
conn.close()

# %%
# Connect to the SQLite3 database
conn = sqlite3.connect('../backend/data/data.db')

# Create a cursor object
cur = conn.cursor()

# Create a new table in the database
cur.execute('CREATE TABLE IF NOT EXISTS user (user_id PRIMARY KEY, gender TEXT, age INTEGER, country TEXT, registered TIMESTAMP, password_hash TEXT)')

for index, row in df_users.iterrows():
    cur.execute('INSERT INTO user (user_id, gender, age, country, registered, password_hash) VALUES (?, ?, ?, ?, ?, ?)', 
                (row['user_id'] , row['gender'], row['age'], row['country'], row['registered'], row['password_hash']))

# Commit the changes and close the database connection
conn.commit()
cur.close()
conn.close()

# %%
# Connect to the SQLite3 database
conn = sqlite3.connect('../backend/data/data.db')

# Create a cursor object
cur = conn.cursor()

# Create a new table in the database
cur.execute('CREATE TABLE IF NOT EXISTS user_track_rate (id INTEGER PRIMARY KEY, user_id TEXT, track_name TEXT, rating INTEGER)')

for index, row in df_UT.iterrows():
    cur.execute('INSERT INTO user_track_rate (id, user_id, track_name, rating) VALUES (?, ?, ?, ?)', 
                (index, row['user_id'], row['track_name'], row['rating']))

# Commit the changes and close the database connection
conn.commit()
cur.close()
conn.close()

# %%
# Connect to the SQLite3 database
conn = sqlite3.connect('../backend/data/data.db')

# Create a cursor object
cur = conn.cursor()

# Create a new table in the database
cur.execute('CREATE TABLE IF NOT EXISTS user_artist_rate (id INTEGER PRIMARY KEY, user_id TEXT, artist_name TEXT, rating INTEGER)')

for index, row in df_UA.iterrows():
    cur.execute('INSERT INTO user_artist_rate (id, user_id, artist_name, rating) VALUES (?, ?, ?, ?)', 
                (index, row['user_id'], row['artist_name'], row['rating']))

# Commit the changes and close the database connection
conn.commit()
cur.close()
conn.close()

# %%
conn = sqlite3.connect('../backend/data/data.db')

# Create a cursor object
cur = conn.cursor()

# Create a new table in the database
cur.execute('CREATE TABLE IF NOT EXISTS artist_track (id INTEGER PRIMARY KEY, artist_name TEXT, track_name TEXT)')

for index, row in df_artist_track.iterrows():
    cur.execute('INSERT INTO artist_track (id, artist_name, track_name) VALUES (?, ?, ?)', 
                (index, row['artist_name'], row['track_name']))

# Commit the changes and close the database connection
conn.commit()
cur.close()
conn.close()

# %% [markdown]
# # **Creación de modelo de filtrado colaborativo basado en similitud con usuarios o items cercanos**
#
# Surprise cuenta con la implementación de los modelos colaborativos dentro de la clase [KNNBasic] (https://surprise.readthedocs.io/en/stable/knn_inspired.html)
#
# El modelo recibe los siguientes parámetros:
#
#
# *   k: El máximo número de vecinos con el que se hará la extrapolación
# *   min_k : El mínimo número de vecinos con el que se extrapolará un rating
# *   sim_options : Opciones de similitud pasadas como un diccionario de python, aqui se le configura al modelo el tipo de similitud a usar para encontrar los vecinos y si la extrapolación debe hacerse usando usuarios o items similares. Revise el formato y similitudes disponibles en surprise en [este link](https://surprise.readthedocs.io/en/stable/prediction_algorithms.html#similarity-measure-configuration)

# %%
# Leer los CSV para no tener que generarlos de nuevo del DataSet original
df_UA_C = pd.read_csv('../data/processed/user_artist.csv', sep=',',  index_col='id')
df_UA_C
# Out:
#             user_id              artist_name  rating
# id
# 0       user_000008               Kanye West   26496
# 1       user_000141                Chemistry   25609
# 2       user_000499                The Knife   18597
# 3       user_000889                 Soilwork   15566
# 4       user_000084           Britney Spears   14614
# ...             ...                      ...     ...
# 897414  user_000593           Chris & Mollie       1
# 897415  user_000593   Celestial Aeon Project       1
# 897416  user_000593              Carla Bruni       1
# 897417  user_000082  Tymon & The Transistors       1
# 897418  user_000524                  Rumskib       1
#
# [897419 rows x 3 columns]

# %%
df_UA_C.loc[df_UA['user_id'] == 'user_000084']
# Out:
#             user_id          artist_name  rating
# id
# 4       user_000084       Britney Spears   14614
# 1122    user_000084                 Muse    1161
# 1877    user_000084    Justin Timberlake     870
# 2123    user_000084              Madonna     806
# 2574    user_000084  The Black Eyed Peas     716
# ...             ...                  ...     ...
# 886962  user_000084          Diana Krall       1
# 886968  user_000084              Eluvium       1
# 886988  user_000084   Efectos Especiales       1
# 887002  user_000084              Dj Damn       1
# 887011  user_000084          Duran Duran       1
#
# [426 rows x 3 columns]

# %%
# Leer los CSV para no tener que generarlos de nuevo del DataSet original
df_UA = pd.read_csv('../data/processed/user_artist_rate.csv', sep=',',  index_col='id')
df_UA
# Out:
#             user_id              artist_name  rating
# id
# 0       user_000008               Kanye West     5.0
# 1       user_000141                Chemistry     5.0
# 2       user_000499                The Knife     5.0
# 3       user_000889                 Soilwork     5.0
# 4       user_000084           Britney Spears     5.0
# ...             ...                      ...     ...
# 897414  user_000593           Chris & Mollie     1.0
# 897415  user_000593   Celestial Aeon Project     1.0
# 897416  user_000593              Carla Bruni     1.0
# 897417  user_000082  Tymon & The Transistors     1.0
# 897418  user_000524                  Rumskib     1.0
#
# [897419 rows x 3 columns]

# %%
# Leer los CSV para no tener que generarlos de nuevo del DataSet original
df_UT = pd.read_csv('../data/processed/user_track_rate.csv', sep=',', index_col='id')
df_UT
# Out:
#              user_id                              track_name    rating
# id
# 0        user_000008                               Heartless  5.000000
# 1        user_000008                See You In My Nightmares  4.905571
# 2        user_000008                            Say You Will  4.898017
# 3        user_000008                           Love Lockdown  4.886686
# 4        user_000008  Welcome To Heartbreak (Feat. Kid Cudi)  4.886686
# ...              ...                                     ...       ...
# 4407905  user_000593                 A Billion Tons Of Light  1.000000
# 4407906  user_000152                                Muskogee  1.000000
# 4407907  user_000593                         A Brighter Beat  1.000000
# 4407908  user_000152                        Mun Täytyy Mennä  1.000000
# 4407909  user_000515              The Theme Of The Anti-Hero  1.000000
#
# [4407910 rows x 3 columns]

# %%
# Método para obtener N registros de cada usuario de un Dataframe
def obtener_N_elementos(df, N):
    df_data = pd.DataFrame()
    usuarios = df['user_id'].unique()
    
    for userId in usuarios:
        df_user = df.loc[df['user_id'] == userId][:N]
        df_data = pd.concat([df_data, df_user])
    
    return df_data

# %%
df_ut_sample = obtener_N_elementos(df_UT, 20)
df_ut_sample
# Out:
#              user_id                                   track_name    rating
# id
# 0        user_000008                                    Heartless  5.000000
# 1        user_000008                     See You In My Nightmares  4.905571
# 2        user_000008                                 Say You Will  4.898017
# 3        user_000008                                Love Lockdown  4.886686
# 4        user_000008       Welcome To Heartbreak (Feat. Kid Cudi)  4.886686
# ...              ...                                          ...       ...
# 4222982  user_000538                                   Poetry Boy  1.000000
# 4222983  user_000538                                   Procession  1.000000
# 4222984  user_000538                                    Rabenwald  1.000000
# 4222985  user_000538                                     Track  9  1.000000
# 4222986  user_000538  What'S Wrong With Me (Nouvelle Vogue Remix)  1.000000
#
# [19724 rows x 3 columns]

# %%
df_ua_sample = obtener_N_elementos(df_UA, 20)
df_ua_sample
# Out:
#             user_id         artist_name    rating
# id
# 0       user_000008          Kanye West  5.000000
# 40      user_000008                T.I.  1.802114
# 473     user_000008            The Fray  1.280053
# 4612    user_000008                Muse  1.075637
# 9114    user_000008         Linkin Park  1.047405
# ...             ...                 ...       ...
# 810683  user_000677  Panic At The Disco  1.000000
# 810684  user_000677                P!Nk  1.000000
# 810685  user_000677             Outkast  1.000000
# 810688  user_000677                 Nas  1.000000
# 810713  user_000677         Nick Carter  1.000000
#
# [19663 rows x 3 columns]

# %% [markdown]
# # 1. user-user usando Tracks y Cosine

# %%
# Primera predicción, usando df_UT. User-User y Cosine
reader = Reader( rating_scale = ( 1, 5 ) )
#Se crea el dataset a partir del dataframe
surprise_dataset = Dataset.load_from_df( df_UT[['user_id', 'track_name', 'rating']], reader )

train_set, test_set=  train_test_split(surprise_dataset, test_size=.2)

# %%
sim_options = {'name': 'cosine',
               'user_based': True # calcule similitud user-user
               }

algo = KNNWithZScore(k=10, min_k=2, sim_options=sim_options)

# %%
df_UT.loc[df_UT['user_id'] == 'user_000084']
# Out:
#              user_id                   track_name    rating
# id
# 24       user_000084                   Gimme More  5.000000
# 40       user_000084                  Piece Of Me  4.130608
# 51       user_000084                    Womanizer  3.943170
# 95       user_000084                        Radar  3.129611
# 135      user_000084                       Circus  2.802592
# ...              ...                          ...       ...
# 2479816  user_000084                  Amor Urbano  1.000000
# 2479819  user_000084                  Amo A Laura  1.000000
# 2479822  user_000084                 American Pie  1.000000
# 2479827  user_000084  Amazing (Feat. Young Jeezy)  1.000000
# 2479828  user_000084           Amanece Junto A Mí  1.000000
#
# [2045 rows x 3 columns]

# %%
algo.fit(train_set)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
algo.predict('user_000084', 'Gimme More')
# Out:
# Prediction(uid='user_000084', iid='Gimme More', r_ui=None, est=2.2716308779406797, details={'actual_k': 10, 'was_impossible': False})

# %%
algo.predict('user_000084', 'Amor Urbano')
# Out:
# Prediction(uid='user_000084', iid='Amor Urbano', r_ui=None, est=1.2603773752481622, details={'actual_k': 2, 'was_impossible': False})

# %%
test_predictions = algo.test(test_set)

# %%
accuracy.rmse( test_predictions, verbose = True )
# Out:
# RMSE: 0.2971
# 0.2971203008692327

# %%
accuracy.mae( test_predictions, verbose = True )
# Out:
# MAE:  0.1671
# 0.16709950484879582

# %% [markdown]
# Modelo over fitting

# %% [markdown]
# # 2. user-user usando Tracks y Pearson

# %%
# Segunda predicción, usando df_UT, User-User y Pearson
reader = Reader( rating_scale = ( 1, 5 ) )
#Se crea el dataset a partir del dataframe
surprise_dataset = Dataset.load_from_df( df_UT[['user_id', 'track_name', 'rating']], reader )

train_set, test_set=  train_test_split(surprise_dataset, test_size=.2)

# %%
sim_options = {'name': 'pearson_baseline',
               'user_based': True # calcule similitud user-user
               }

algo = KNNWithZScore(k=10, min_k=2, sim_options=sim_options)

# %%
df_UT.loc[df_UT['user_id'] == 'user_000084']
# Out:
#              user_id                   track_name    rating
# id
# 24       user_000084                   Gimme More  5.000000
# 40       user_000084                  Piece Of Me  4.130608
# 51       user_000084                    Womanizer  3.943170
# 95       user_000084                        Radar  3.129611
# 135      user_000084                       Circus  2.802592
# ...              ...                          ...       ...
# 2479816  user_000084                  Amor Urbano  1.000000
# 2479819  user_000084                  Amo A Laura  1.000000
# 2479822  user_000084                 American Pie  1.000000
# 2479827  user_000084  Amazing (Feat. Young Jeezy)  1.000000
# 2479828  user_000084           Amanece Junto A Mí  1.000000
#
# [2045 rows x 3 columns]

# %%
algo.fit(train_set)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
algo.predict('user_000084', 'Gimme More')
# Out:
# Prediction(uid='user_000084', iid='Gimme More', r_ui=None, est=3.6078534052641666, details={'actual_k': 10, 'was_impossible': False})

# %%
algo.predict('user_000084', 'Amor Urbano')
# Out:
# Prediction(uid='user_000084', iid='Amor Urbano', r_ui=None, est=1.0610468893619442, details={'actual_k': 1, 'was_impossible': False})

# %%
test_predictions = algo.test(test_set)

# %%
accuracy.rmse( test_predictions, verbose = True )
# Out:
# RMSE: 0.2917
# 0.2917172999339268

# %%
accuracy.mae( test_predictions, verbose = True )
# Out:
# MAE:  0.1670
# 0.16696593843603386

# %% [markdown]
# # 3. item-item usando Tracks y cosine

# %%
df_ut_sample = obtener_N_elementos(df_UT, 20)
df_ut_sample
# Out:
#              user_id                                   track_name    rating
# id
# 0        user_000008                                    Heartless  5.000000
# 1        user_000008                     See You In My Nightmares  4.905571
# 2        user_000008                                 Say You Will  4.898017
# 3        user_000008                                Love Lockdown  4.886686
# 4        user_000008       Welcome To Heartbreak (Feat. Kid Cudi)  4.886686
# ...              ...                                          ...       ...
# 4222982  user_000538                                   Poetry Boy  1.000000
# 4222983  user_000538                                   Procession  1.000000
# 4222984  user_000538                                    Rabenwald  1.000000
# 4222985  user_000538                                     Track  9  1.000000
# 4222986  user_000538  What'S Wrong With Me (Nouvelle Vogue Remix)  1.000000
#
# [19724 rows x 3 columns]

# %%
# Tercera predicción, usando df_UT, Item-Item y cosine
reader = Reader( rating_scale = ( 1, 5 ) )
#Se crea el dataset a partir del dataframe
surprise_dataset = Dataset.load_from_df( df_ut_sample[['user_id', 'track_name', 'rating']], reader )

train_set, test_set=  train_test_split(surprise_dataset, test_size=.2)

# %%
sim_options = {'name': 'cosine',
               'user_based': False # calcule similitud item-item
               }

algo = KNNWithZScore(k=50, min_k=2, sim_options=sim_options)

# %%
df_ut_sample.loc[df_ut_sample['user_id'] == 'user_000084']
# Out:
#           user_id                             track_name    rating
# id
# 24    user_000084                             Gimme More  5.000000
# 40    user_000084                            Piece Of Me  4.130608
# 51    user_000084                              Womanizer  3.943170
# 95    user_000084                                  Radar  3.129611
# 135   user_000084                                 Circus  2.802592
# 149   user_000084                          Break The Ice  2.726820
# 249   user_000084                          If U Seek Amy  2.435693
# 590   user_000084  They Talk Shit About Me (Feat. Verse)  2.000997
# 641   user_000084                             Hot As Ice  1.961117
# 750   user_000084                        Kill The Lights  1.909272
# 800   user_000084                            Toy Soldier  1.885344
# 980   user_000084                        I'M A Slave 4 U  1.813559
# 1060  user_000084                   Me Against The Music  1.785643
# 1284  user_000084                        Shattered Glass  1.725823
# 1522  user_000084                           Ooh Ooh Baby  1.681954
# 1605  user_000084    4 Minutes (Feat. Justin Timberlake)  1.669990
# 1659  user_000084                               The Kill  1.662014
# 1709  user_000084                              Everybody  1.658026
# 1883  user_000084                              Freakshow  1.630110
# 1918  user_000084                                  Toxic  1.626122

# %%
algo.fit(train_set)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.

# %%
algo.predict('user_000084', 'Gimme More')
# Out:
# Prediction(uid='user_000084', iid='Gimme More', r_ui=None, est=3.113965039587819, details={'actual_k': 18, 'was_impossible': False})

# %%
algo.predict('user_000084', 'Ooh Ooh Baby')
# Out:
# Prediction(uid='user_000084', iid='Ooh Ooh Baby', r_ui=None, est=1.8687985986173001, details={'actual_k': 18, 'was_impossible': False})

# %%
test_predictions = algo.test(test_set)

# %%
accuracy.rmse( test_predictions, verbose = True )
# Out:
# RMSE: 1.0546
# 1.0545547503150723

# %%
accuracy.mae( test_predictions, verbose = True )
# Out:
# MAE:  0.8393
# 0.8392575419783215

# %% [markdown]
# # 4. item-item usando Tracks y pearson

# %%
# Cuarta predicción, usando df_UT, Item-Item y Pearson
reader = Reader( rating_scale = ( 1, 5 ) )
#Se crea el dataset a partir del dataframe
surprise_dataset = Dataset.load_from_df( df_ut_sample[['user_id', 'track_name', 'rating']], reader )

train_set, test_set=  train_test_split(surprise_dataset, test_size=.2)

# %%
sim_options = {'name': 'pearson_baseline',
               'user_based': True # calcule similitud item-item
               }

algo = KNNWithZScore(k=50, min_k=2, sim_options=sim_options)

# %%
algo.fit(train_set)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
algo.predict('user_000084', 'Gimme More')
# Out:
# Prediction(uid='user_000084', iid='Gimme More', r_ui=None, est=4.986838331195024, details={'actual_k': 3, 'was_impossible': False})

# %%
algo.predict('user_000084', 'Ooh Ooh Baby')
# Out:
# Prediction(uid='user_000084', iid='Ooh Ooh Baby', r_ui=None, est=1.6819541375872382, details={'actual_k': 1, 'was_impossible': False})

# %%
algo.predict('user_000084', 'Circus')
# Out:
# Prediction(uid='user_000084', iid='Circus', r_ui=None, est=2.801814833741703, details={'actual_k': 2, 'was_impossible': False})

# %%
test_set_df = pd.DataFrame(test_set)
test_set_df
# Out:
#                 0                              1         2
# 0     user_000985                            3Am  3.000000
# 1     user_000043  You'Re A Woman, I'M A Machine  4.333333
# 2     user_000410                           Undo  1.000000
# 3     user_000754       An Hour Before The Light  2.190476
# 4     user_000678                 A Winter'S Sky  4.671233
# ...           ...                            ...       ...
# 3940  user_000601                  Done With You  3.829268
# 3941  user_000314                    Uptown Girl  3.648649
# 3942  user_000916           My One And Only Love  2.333333
# 3943  user_000834                Can You Imagine  3.054054
# 3944  user_000564                         Farrah  3.800000
#
# [3945 rows x 3 columns]

# %%
test_set_df.loc[test_set_df[0] == 'user_000829']
# Out:
#                 0                        1         2
# 0     user_000829        Ain'T No Easy Way  3.793103
# 1026  user_000829  Communication Breakdown  3.379310
# 1656  user_000829     Cigarettes & Alcohol  4.103448
# 2608  user_000829       Wish You Were Here  3.689655
# 2786  user_000829            Gimme Shelter  3.586207

# %%
df_ut_sample.loc[df_ut_sample['user_id'] == 'user_000829']
# Out:
#            user_id                track_name    rating
# id
# 4101   user_000829              Live Forever  5.000000
# 5383   user_000829        Rock 'N' Roll Star  4.551724
# 6152   user_000829                 Acquiesce  4.379310
# 7482   user_000829      Cigarettes & Alcohol  4.103448
# 7847   user_000829          Spread Your Love  4.034483
# 8036   user_000829       Champagne Supernova  4.000000
# 8792   user_000829                Love Burns  3.896552
# 9225   user_000829                    Rifles  3.827586
# 9624   user_000829         Ain'T No Easy Way  3.793103
# 10302  user_000829  Don'T Look Back In Anger  3.689655
# 10338  user_000829          Comfortably Numb  3.689655
# 10388  user_000829        Wish You Were Here  3.689655
# 10538  user_000829         Shuffle Your Feet  3.689655
# 11169  user_000829                     Money  3.620690
# 11480  user_000829             Gimme Shelter  3.586207
# 12755  user_000829       Weight Of The World  3.448276
# 13105  user_000829     Bitter Sweet Symphony  3.448276
# 13657  user_000829            The Masterplan  3.379310
# 13671  user_000829             Rock And Roll  3.379310
# 13861  user_000829   Communication Breakdown  3.379310

# %%
algo.predict('user_000829', "Ain'T No Easy Way")
# Out:
# Prediction(uid='user_000829', iid="Ain'T No Easy Way", r_ui=None, est=3.222970235312451, details={'actual_k': 1, 'was_impossible': False})

# %%
algo.predict('user_000829', 'Gimme Shelter')
# Out:
# Prediction(uid='user_000829', iid='Gimme Shelter', r_ui=None, est=2.876436781609195, details={'actual_k': 1, 'was_impossible': False})

# %%
algo.predict('user_000829', 'Circus')
# Out:
# Prediction(uid='user_000829', iid='Circus', r_ui=None, est=2.784354626042703, details={'actual_k': 0, 'was_impossible': False})

# %%
test_predictions = algo.test(test_set)

# %%
accuracy.rmse( test_predictions, verbose = True )
# Out:
# RMSE: 1.0471
# 1.0470716265757551

# %%
accuracy.mae( test_predictions, verbose = True )
# Out:
# MAE:  0.8284
# 0.8283656497879321

# %%
def model_prediction(table, id, model):
    
    songs = table['track_name'].unique()
    predictions = []
    escuchadas = table.loc[table['user_id'] == id]['track_name'].to_list()
    for i in table['track_name'].unique():
        if i not in escuchadas:
            predictions.append(model.predict(id, i))
    predictions.sort(key=lambda x : x.est, reverse=True)
    #Se convierte a dataframe
    labels = ['track_name', 'estimation']
    df_predictions = pd.DataFrame.from_records(list(map(lambda x: (x.iid, x.est) , predictions)), columns=labels)
 
    # Lo unimos con el dataframe de películas PENDIENTE
    # df_predictions = df_predictions.merge(items[['track_name','movie title','IMDb URL ']], how='left', on='movie id')

    return df_predictions

# %%
model_prediction(df_ut_sample, 'user_000829', algo)
# Out:
#                                   track_name  estimation
# 0                                  Heartless    3.917241
# 1                               Say You Will    3.917241
# 2                              Love Lockdown    3.917241
# 3                Paranoid (Feat. Mr. Hudson)    3.917241
# 4                Amazing (Feat. Young Jeezy)    3.917241
# ...                                      ...         ...
# 14735                                   Suki    3.198910
# 14736  The End Result Of 11 Months In Prison    3.198910
# 14737                           Out Of Reach    3.198910
# 14738                  The Ghosts Around You    3.198910
# 14739                             Tidal Wave    3.198910
#
# [14740 rows x 2 columns]

# %%
algo.predict('user_000829', 'Wings Of Words')
# Out:
# Prediction(uid='user_000829', iid='Wings Of Words', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False})

# %%
model_prediction(df_ut_sample, 'user_000084', algo)
# Out:
#                                             track_name  estimation
# 0                             See You In My Nightmares    3.198910
# 1               Welcome To Heartbreak (Feat. Kid Cudi)    3.198910
# 2                                       Coldest Winter    3.198910
# 3      Pinocchio Story (Freestyle Live From Singapore)    3.198910
# 4                                   Ready For Whatever    3.198910
# ...                                                ...         ...
# 14735                                       Poetry Boy    2.327781
# 14736                                       Procession    2.327781
# 14737                                        Rabenwald    2.327781
# 14738                                         Track  9    2.327781
# 14739      What'S Wrong With Me (Nouvelle Vogue Remix)    2.327781
#
# [14740 rows x 2 columns]

# %%
model_prediction(df_ut_sample, 'user_000141', algo)
# Out:
#                                             track_name  estimation
# 0                             See You In My Nightmares    3.198910
# 1               Welcome To Heartbreak (Feat. Kid Cudi)    3.198910
# 2                                       Coldest Winter    3.198910
# 3      Pinocchio Story (Freestyle Live From Singapore)    3.198910
# 4                                   Ready For Whatever    3.198910
# ...                                                ...         ...
# 14735                                       Poetry Boy    2.754001
# 14736                                       Procession    2.754001
# 14737                                        Rabenwald    2.754001
# 14738                                         Track  9    2.754001
# 14739      What'S Wrong With Me (Nouvelle Vogue Remix)    2.754001
#
# [14740 rows x 2 columns]

# %%
model_prediction(df_ut_sample, 'user_000345', algo)
# Out:
#                                   track_name  estimation
# 0                                      Intro    4.208178
# 1                                  Heartless    3.894118
# 2                               Say You Will    3.894118
# 3                              Love Lockdown    3.894118
# 4                Paranoid (Feat. Mr. Hudson)    3.894118
# ...                                      ...         ...
# 14735                                   Suki    3.198910
# 14736  The End Result Of 11 Months In Prison    3.198910
# 14737                           Out Of Reach    3.198910
# 14738                  The Ghosts Around You    3.198910
# 14739                             Tidal Wave    3.198910
#
# [14740 rows x 2 columns]

# %%
algo.predict('user_000692', 'Wings Of Words')
# Out:
# Prediction(uid='user_000692', iid='Wings Of Words', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False})

# %%
algo.predict('user_000084', 'Gimme More')
# Out:
# Prediction(uid='user_000084', iid='Gimme More', r_ui=None, est=4.986838331195024, details={'actual_k': 3, 'was_impossible': False})

# %%
len(df_ut_sample['track_name'].unique())
# Out:
# 14760

# %%
predictions = []
# df_ut_sample_u = df_ut_sample.loc[df_ut_sample['user_id'] != 'user_000829']
# df_ut_sample_u
escuchadas = df_ut_sample.loc[df_ut_sample['user_id'] == 'user_000829']['track_name'].to_list()
for i in df_ut_sample['track_name'].unique():
    if i not in escuchadas:
        predictions.append(algo.predict('user_000829', i))
    
predictions
# Out:
# [Prediction(uid='user_000829', iid='Heartless', r_ui=None, est=4.069736366919466, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='See You In My Nightmares', r_ui=None, est=4.905571293673277, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Say You Will', r_ui=None, est=4.898016997167139, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Love Lockdown', r_ui=None, est=4.15920180704097, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Welcome To Heartbreak (Feat. Kid Cudi)', r_ui=None, est=4.886685552407933, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Coldest Winter', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Paranoid (Feat. Mr. Hudson)', r_ui=None, est=3.3802329241422724, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Amazing (Feat. Young Jeezy)', r_ui=None, est=3.4, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Pinocchio Story (Freestyle Live From Singapore)', r_ui=None, est=4.852691218130312, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Bad News', r_ui=None, est=4.824362606232295, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Robocop', r_ui=None, est=3.6754800125904943, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Street Lights', r_ui=None, est=3.4025974025974026, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='56 Bars (Intro)', r_ui=None, est=1.6421152030217183, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Live Your Life (Feat. Rihanna)', r_ui=None, est=1.640226628895184, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Ready For Whatever', r_ui=None, est=1.6364494806421153, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='No Matter What', r_ui=None, est=1.6345609065155808, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Dead And Gone (Feat. Justin Timberlake)', r_ui=None, est=1.88, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='My Life Your Entertainment (Feat. Usher)', r_ui=None, est=1.6345609065155808, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="I'M Illy", r_ui=None, est=1.6326723323890464, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='On Top Of The World (Feat. Ludacris & B.O.B.)', r_ui=None, est=1.6288951841359776, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Jolene', r_ui=None, est=3.144927536231884, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Heartbeats', r_ui=None, est=3.5834948136647826, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Staring At The Sun', r_ui=None, est=4.064224327993014, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Swing', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Anthems For A Seventeen Year Old Girl', r_ui=None, est=3.8992474916387962, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='St. Ides Heaven', r_ui=None, est=4.497252747252748, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Bonus Track', r_ui=None, est=2.7789495450785773, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='My Angel Rocks Back And Forth', r_ui=None, est=3.826923076923077, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='How Long Will It Take', r_ui=None, est=3.6840659340659343, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Pedro The Lion - Track 07', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Beast Of Burden', r_ui=None, est=3.527472527472528, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Blue Light', r_ui=None, est=3.9089548409168664, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Suicide Medicine', r_ui=None, est=3.478021978021978, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Seventeen Years', r_ui=None, est=3.5104733975701716, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Fire Maple Song', r_ui=None, est=3.381868131868132, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Slowly', r_ui=None, est=4.248962148962149, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='White Daisy Passing', r_ui=None, est=3.066979341257557, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Disco Science', r_ui=None, est=3.4977522477522482, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Pilot', r_ui=None, est=3.129120879120879, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Non-Stop Party Now', r_ui=None, est=3.101648351648352, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Wings Of Words', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Wings Of Words (Instrumental)', r_ui=None, est=4.51009046624913, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='キミがいる', r_ui=None, est=3.633263743910925, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Primal Innocence', r_ui=None, est=4.248434237995825, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Almost In Love', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='約束の場所', r_ui=None, est=2.8343771746694504, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Wings Of Words [Tv Size]', r_ui=None, est=2.67571329157968, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Shissou (Tv Size)', r_ui=None, est=2.622825330549756, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='それから', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='悠久の旅路', r_ui=None, est=2.514265831593597, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='伝説の草原', r_ui=None, est=2.416840640222686, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='モノクローム Lost In You', r_ui=None, est=2.3778705636743216, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Innocent Sorrow (Tv Size)', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='We Are One', r_ui=None, est=2.32776617954071, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='It Takes Two', r_ui=None, est=2.2609603340292272, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Invoke -インヴォーク-', r_ui=None, est=2.2386917188587336, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Wings Of Words (Alas De Palabras)', r_ui=None, est=2.1440501043841333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Top Of The World', r_ui=None, est=2.0688935281837164, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='伝説の草原 (Patrick Stump Remix)', r_ui=None, est=2.0633263743910923, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Grind For Me', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='La Paloma', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Intro', r_ui=None, est=3.7975735446165424, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="You Know I'M No Good", r_ui=None, est=3.1248104317335086, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Tag Am Meer (Unplugged)', r_ui=None, est=1.4911242603550297, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Me & Mr Jones', r_ui=None, est=2.290277881806606, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Rockferry', r_ui=None, est=2.4959456497918033, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Können Diese Augen Lügen', r_ui=None, est=1.467455621301775, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Just Friends', r_ui=None, est=2.230769230769231, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='He Can Only Hold Her', r_ui=None, est=1.4615384615384617, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Wake Up Alone', r_ui=None, est=2.2560856864654335, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Warwick Avenue', r_ui=None, est=1.4585798816568047, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Some Unholy War', r_ui=None, est=1.4585798816568047, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Rehab', r_ui=None, est=3.100639846756714, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Hanging On Too Long', r_ui=None, est=3.518518518518518, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Back To Black', r_ui=None, est=2.767543859649123, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Tears Dry On Their Own', r_ui=None, est=3.4050632911392404, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Stepping Stone', r_ui=None, est=3.2263313609467454, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="I'M Scared", r_ui=None, est=3.3703703703703702, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Syrup & Honey', r_ui=None, est=1.4497041420118344, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Delayed Devotion', r_ui=None, est=3.3703703703703702, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="Je T'Aime...Moi Non Plus", r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="Als M'N Hoofd M'N Hart Vertrouwt", r_ui=None, est=2.493055555555556, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Siren', r_ui=None, est=2.4791666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Prison Break Anthem', r_ui=None, est=2.204861111111111, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='No One', r_ui=None, est=2.083333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Rain Down On Me', r_ui=None, est=1.7996031746031744, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Mon Essentiel', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='La Camisa Negra', r_ui=None, est=2.0, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Porque Te Vas', r_ui=None, est=1.9131944444444444, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Po Prostu Miłość', r_ui=None, est=1.9131944444444444, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Dla Ciebie', r_ui=None, est=1.8125, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Emmanuelle', r_ui=None, est=1.75, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Lost!', r_ui=None, est=3.050151064213564, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Apologize', r_ui=None, est=2.6045567324437946, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Give It To Me', r_ui=None, est=2.4207702020202024, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="Don'T Be A Stranger", r_ui=None, est=1.6527777777777777, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Every Word', r_ui=None, est=1.6284722222222223, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Time To Pray', r_ui=None, est=1.6145833333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Slaap Maar', r_ui=None, est=1.59375, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Trzy Dni', r_ui=None, est=1.5763888888888888, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Gimme More', r_ui=None, est=3.6952985129294555, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Piece Of Me', r_ui=None, est=3.4344123167861205, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Womanizer', r_ui=None, est=3.7702003012345826, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Radar', r_ui=None, est=3.0431795303255313, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Circus', r_ui=None, est=2.865839865217724, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Break The Ice', r_ui=None, est=2.9520753429959883, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='If U Seek Amy', r_ui=None, est=3.0579826515977793, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='They Talk Shit About Me (Feat. Verse)', r_ui=None, est=2.000997008973081, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Hot As Ice', r_ui=None, est=1.9611166500498505, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Kill The Lights', r_ui=None, est=2.4082784758307856, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Toy Soldier', r_ui=None, est=1.8853439680957127, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="I'M A Slave 4 U", r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Me Against The Music', r_ui=None, est=1.785643070787637, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Shattered Glass', r_ui=None, est=1.7258225324027916, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Ooh Ooh Baby', r_ui=None, est=1.9952817045552085, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='4 Minutes (Feat. Justin Timberlake)', r_ui=None, est=3.5906600040621335, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Kill', r_ui=None, est=2.660605312774548, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Everybody', r_ui=None, est=1.6580259222333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Freakshow', r_ui=None, est=2.1044588090034533, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Toxic', r_ui=None, est=1.626121635094716, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="If I Don'T Live Today, Then I Might Be Here Tomorrow", r_ui=None, est=3.5267857142857144, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Travelling Riverside Blues', r_ui=None, est=3.1668472372697725, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Welcome Home, Luc Robitaille', r_ui=None, est=3.0021668472372696, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='If I Leave You', r_ui=None, est=2.2047670639219934, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Leave Before The Lights Come On', r_ui=None, est=2.2047670639219934, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Harder Than You Think', r_ui=None, est=2.131094257854821, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='You Only Live Once', r_ui=None, est=2.6487455197132617, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Clean Town', r_ui=None, est=2.087757313109426, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='A Certain Romance', r_ui=None, est=2.9168422890756895, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Wildfire', r_ui=None, est=2.009750812567714, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Song For Aberdeen', r_ui=None, est=2.0554190527782077, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='She Moves In Her Own Way', r_ui=None, est=3.4866854093148127, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Kinks / Victoria', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid="We'Re Gonna Groove", r_ui=None, est=1.836403033586132, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Ocean', r_ui=None, est=1.8320693391115923, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='P.U.S.A', r_ui=None, est=1.8104008667388949, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Meantime', r_ui=None, est=1.7670639219934994, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Someday', r_ui=None, est=3.1422499623733517, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Juicebox', r_ui=None, est=1.7280606717226434, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Distortion Sleep', r_ui=None, est=3.2857142857142856, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Jailbreak', r_ui=None, est=2.7140428162918306, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Rejection Role', r_ui=None, est=2.807017543859649, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="I'M Alive", r_ui=None, est=2.333333333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Freelancer (Bonus Track)', r_ui=None, est=2.649122807017544, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Land Of Confusion', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Spirits Of The Future Sun', r_ui=None, est=2.539473684210526, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Aftermath', r_ui=None, est=3.7434210526315788, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Stabbing The Drama', r_ui=None, est=2.7713577421815407, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Machinegun Majesty', r_ui=None, est=2.3464912280701755, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Follow The Hollow', r_ui=None, est=2.2850877192982457, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Sons Of Plunder', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Psychic Suicide', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Stricken', r_ui=None, est=3.4451754385964914, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='One With The Flies', r_ui=None, est=2.2149122807017543, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Pain Redefined', r_ui=None, est=2.12280701754386, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Mindfields', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Ten Thousand Fists', r_ui=None, est=2.654927760577915, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Flashback', r_ui=None, est=2.070175438596491, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Black Star Deceiver', r_ui=None, est=2.0657894736842106, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Bright Lights', r_ui=None, est=4.636363636363637, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Better Alone', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Downfall', r_ui=None, est=4.359818388195233, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='All I Need', r_ui=None, est=3.2787229802432205, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Unwell', r_ui=None, est=2.868259400174294, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Beautiful Intentions', r_ui=None, est=2.902383654937571, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Disease', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Lonely No More', r_ui=None, est=2.7480136208853576, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Last Night On Earth', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Love Foolosophy', r_ui=None, est=2.466515323496027, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='When The Heartache Ends', r_ui=None, est=2.434733257661748, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='They', r_ui=None, est=2.375709421112372, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Breathe (2 Am)', r_ui=None, est=2.343927355278093, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='I Want You Back', r_ui=None, est=2.9870110113858432, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Black Coffee', r_ui=None, est=2.2037973377360434, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Bent', r_ui=None, est=2.388951948543322, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Here It Comes Again', r_ui=None, est=2.125993189557321, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='That Day', r_ui=None, est=2.10783200908059, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Feel', r_ui=None, est=3.205642147227375, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Just A Ride', r_ui=None, est=2.735754824063564, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Ryoujoku No Ame', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid="Ain'T Afraid To Die", r_ui=None, est=4.886234357224118, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Itoshii Hito', r_ui=None, est=4.422070534698521, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Somnus Memoria', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Kekkonshiki No Uta ~Kisetsu Hazure No Wedding March~', r_ui=None, est=3.862343572241184, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Conceived Sorrow', r_ui=None, est=2.6197641948495187, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="Saishuu Ressha 70'S Ver.", r_ui=None, est=3.5437997724687147, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Sugao', r_ui=None, est=3.3526734926052333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Namamekashiki Ansoku, Tamerai Ni Hohoemi', r_ui=None, est=3.2935153583617742, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Pledge', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='少年 -Screw Mix-', r_ui=None, est=3.0113765642775885, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Kasa Ga Nai', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='The Promised Land', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Ame No Orchestra', r_ui=None, est=2.824800910125142, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Where Is My Mind', r_ui=None, est=3.32149136415348, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Boukyaku No Sora', r_ui=None, est=2.715585893060296, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Rev 22:20', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Sinner', r_ui=None, est=2.697383390216155, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Dorisu Kara No Tegami', r_ui=None, est=2.6336746302616607, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Mushi', r_ui=None, est=2.5790671217292376, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Rock On', r_ui=None, est=3.6666666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Lo Que Quieres Ver', r_ui=None, est=3.327653997378768, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Utopia', r_ui=None, est=3.0969855832241158, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Arpeggio', r_ui=None, est=3.091743119266055, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Run Into Flowers (Midnight Fuck Remix By Jackson)', r_ui=None, est=2.593709043250328, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Fast Life', r_ui=None, est=2.4626474442988204, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="Tv Dogs (Cathodica'S Letter) (Feat. Mike Ladd)", r_ui=None, est=2.410222804718217, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Silencio De Amor', r_ui=None, est=2.378768020969856, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Future', r_ui=None, est=2.9948634444047286, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Darling', r_ui=None, est=2.347313237221494, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Skyline', r_ui=None, est=2.331585845347313, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Trick Or Treatz', r_ui=None, est=2.2424639580602883, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Can I Scream', r_ui=None, est=2.074705111402359, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Trabajando En El Sol', r_ui=None, est=2.017038007863696, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Over And Over', r_ui=None, est=3.6603032704933685, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Hands Around My Throat', r_ui=None, est=3.666666666666667, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Poney, Part 2', r_ui=None, est=1.90694626474443, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Covenant', r_ui=None, est=1.8964613368283088, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Dexter', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Autobahn Music Box', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Stop And Stare', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Perfect Lover', r_ui=None, est=3.087417218543046, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Seize The Day', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Radio', r_ui=None, est=3.741048478995161, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Do It Again', r_ui=None, est=2.9235018575351317, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="Time Won'T Let Me Go", r_ui=None, est=2.5311258278145696, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Runaway', r_ui=None, est=4.155476585327332, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Heaven On Earth', r_ui=None, est=2.3986754966887416, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Love, Sweat And Beer', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Invaders Must Die', r_ui=None, est=4.874822190611664, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Propane Nightmares', r_ui=None, est=3.7019930230977764, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Other Side', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Granite', r_ui=None, est=3.999056114648835, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Propane', r_ui=None, est=3.6230440967283073, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Hey!', r_ui=None, est=2.9743954480796586, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Get Smashed Gate Crash', r_ui=None, est=2.951635846372689, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Declaration Of War', r_ui=None, est=2.9402560455192037, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Mutiny', r_ui=None, est=3.531261216947395, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='What She Did', r_ui=None, est=2.6955903271692745, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="Warrior'S Dance", r_ui=None, est=2.5032476991893606, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Tempest', r_ui=None, est=2.8138701065882032, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Other Side (Vip Mix)', r_ui=None, est=2.4793741109530583, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='All Blue', r_ui=None, est=2.3143669985775253, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Leap Of Faith', r_ui=None, est=2.268847795163585, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Liquid Lives', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Girls', r_ui=None, est=2.4163637321532057, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Come Around (Rmx)', r_ui=None, est=2.069701280227596, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Untitled', r_ui=None, est=3.3439655238609616, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='[Untitled]', r_ui=None, est=3.959811509564986, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Lost Keys (Blame Hofmann)', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Rosetta Stoned', r_ui=None, est=2.6869565217391305, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Untitled 4', r_ui=None, est=3.853940217391304, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Gobbledigook', r_ui=None, est=2.373913043478261, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Jambi', r_ui=None, est=3.025497420781135, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Right In Two', r_ui=None, est=2.315942028985507, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Vicarious', r_ui=None, est=3.4108445777111447, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Inní Mér Syngur Vitleysingur', r_ui=None, est=3.3661971830985915, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Glósóli', r_ui=None, est=3.788530465949821, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Pedafly', r_ui=None, est=2.1536231884057973, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Takk...', r_ui=None, est=2.8795913518650513, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Lipan Conjuring', r_ui=None, est=3.606451612903226, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='D-Rider', r_ui=None, est=2.026086956521739, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Untitled #4', r_ui=None, est=3.4956521739130437, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Psychedelic Warlords (Disappear In Smoke)', r_ui=None, est=1.9855072463768115, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Heysátan', r_ui=None, est=2.548684916800859, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Hoppípolla', r_ui=None, est=3.6944887951992427, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='White Rhino Tea', r_ui=None, est=1.95072463768116, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Fight With Shattered Mirrors', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='We Are The People', r_ui=None, est=3.5041323308270673, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Miles Away', r_ui=None, est=2.986133333333333, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='If You Go Away', r_ui=None, est=2.0816, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Rock Steady', r_ui=None, est=1.9344, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Humanitarianism', r_ui=None, est=1.8512, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Dawn/Night', r_ui=None, est=1.7616, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Pressurized Chamber', r_ui=None, est=1.7168, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Magnetic Electric [Bonus Track]', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Tar Heart', r_ui=None, est=1.6656, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Le Monde Est Stone - Starmania', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Wrecked Metal', r_ui=None, est=1.6464, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Avalon (Jacques Lu Cont Remix)', r_ui=None, est=1.6336, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Bunny', r_ui=None, est=1.608, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Black Milk', r_ui=None, est=2.287073684210527, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Dress', r_ui=None, est=2.5532500000000002, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Cuffs', r_ui=None, est=1.544, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Lake', r_ui=None, est=1.5248, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="That'S Not My Name", r_ui=None, est=2.599666630527678, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Be My Baby', r_ui=None, est=3.436619718309859, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Evil', r_ui=None, est=3.7003772001548327, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Postcard Of A Painting', r_ui=None, est=2.9639934533551555, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Matchbox', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Sewn', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Push', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Set The Fire To The Third Bar', r_ui=None, est=3.0297137028866907, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Apply Some Pressure', r_ui=None, est=3.1198684557451477, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Volcano', r_ui=None, est=1.9819967266775775, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Roseability', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='The Great Escape', r_ui=None, est=3.7424307913965214, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Stupify', r_ui=None, est=1.8117839607201311, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Glorious', r_ui=None, est=2.6677967422648274, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Say Hello To The Angels', r_ui=None, est=1.7855973813420625, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="C'Mere", r_ui=None, est=3.814814814814815, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='When The Night Feels My Song', r_ui=None, est=2.7311767870481525, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Bus Song', r_ui=None, est=1.733224222585925, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Take You On A Cruise', r_ui=None, est=3.144124913134698, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Ever Fallen In Love?', r_ui=None, est=1.67430441898527, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='California', r_ui=None, est=3.314131880402246, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Fullness Of Wind', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='First Light', r_ui=None, est=3.649180327868853, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='7.25', r_ui=None, est=3.59672131147541, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='2/2', r_ui=None, est=3.2557377049180327, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Dot Gain', r_ui=None, est=3.091803278688525, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Epaule Tatoo', r_ui=None, est=2.59344262295082, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Up The Down Escalator', r_ui=None, est=2.495081967213115, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Strange Lights', r_ui=None, est=2.4491803278688526, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Lesson No. 1 For Electric Guitar', r_ui=None, est=2.442622950819672, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Week-End À Rome', r_ui=None, est=2.344262295081968, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Through The Portal (Live)', r_ui=None, est=2.3311475409836064, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Wake Up And Go Berserk', r_ui=None, est=2.2852459016393443, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='I Do Have Weapons', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Michael', r_ui=None, est=2.8923144720606375, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='On The Wall', r_ui=None, est=2.1475409836065573, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Prize (Demo)', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Calvary Scars', r_ui=None, est=2.101639344262295, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='New Jersey', r_ui=None, est=2.0754098360655737, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Fight', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Nu Eller Aldrig', r_ui=None, est=3.616393442622951, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Teardrops', r_ui=None, est=3.2622950819672134, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='My Number One', r_ui=None, est=3.019672131147541, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Hypnotized', r_ui=None, est=3.1728854834877644, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Ahava Ktana', r_ui=None, est=2.540983606557377, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Gigolo', r_ui=None, est=2.514754098360656, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Secret Combination', r_ui=None, est=2.363934426229508, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='My Number One (Live Eurovision Song Contest 2005 Final)', r_ui=None, est=2.304918032786885, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='I Love You Mi Vida', r_ui=None, est=2.239344262295082, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Det Finaste Någon Kan Få', r_ui=None, est=2.2327868852459014, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='With Love', r_ui=None, est=2.3310634720470786, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Molitva', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Déjà Vu', r_ui=None, est=2.088524590163934, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='An Eihes Erthei Pio Noris', r_ui=None, est=2.081967213114754, details={'actual_k': 0, 'was_impossible': False}),
# ...
#  Prediction(uid='user_000829', iid='When You Sleep', r_ui=None, est=2.033707865168539, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='This Must Be The Place (Naive Melody)', r_ui=None, est=1.9325842696629207, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='To Here Knows When', r_ui=None, est=3.0000000000000004, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='I Would Die 4 U', r_ui=None, est=1.8876404494382024, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Eye Know', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Blown A Wish', r_ui=None, est=2.612115290669272, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Who Could Win A Rabbit', r_ui=None, est=2.632334581772784, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Making Flippy Floppy', r_ui=None, est=1.820224719101124, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='I Only Said', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Slippery People', r_ui=None, est=1.808988764044944, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='3 Gymnopédies', r_ui=None, est=1.797752808988764, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Todo Los Dolores', r_ui=None, est=1.797752808988764, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Girlfriend Is Better', r_ui=None, est=1.7752808988764044, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Bucky Done Gun', r_ui=None, est=1.7640449438202248, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Pull Up The Roots', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Nasty Sound', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The World Is Mine (Album Version)', r_ui=None, est=3.1468926553672314, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='What Else Is There', r_ui=None, est=2.935969868173258, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='You Make It Easy', r_ui=None, est=2.3807017543859645, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Toop Toop', r_ui=None, est=2.8159806295399514, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Tracking Treasure Down', r_ui=None, est=2.536723163841808, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Run', r_ui=None, est=3.339298223612394, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Dance I Said (Soulcast Remix)', r_ui=None, est=2.5028248587570623, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Kelly Watch The Stars', r_ui=None, est=3.47923498531674, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Sound Of Violence', r_ui=None, est=2.3559322033898304, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='No More Conversations', r_ui=None, est=2.3446327683615817, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="La Femme D'Argent", r_ui=None, est=3.5882352941176467, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Remember', r_ui=None, est=3.49492207139266, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Talisman', r_ui=None, est=2.892130735675573, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Playground Love', r_ui=None, est=3.343504710192744, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Mike Mills', r_ui=None, est=2.670613729587493, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='A Star Is Born', r_ui=None, est=2.1864406779661016, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Bus Stop Bitties', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Lux Libera Nos', r_ui=None, est=3.0630372492836675, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Only One', r_ui=None, est=3.280992224114553, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Calling All Angels', r_ui=None, est=2.925501432664756, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Mad World', r_ui=None, est=3.4824837030987297, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Take Me Away', r_ui=None, est=2.922150454081881, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Ingel', r_ui=None, est=2.7421203438395416, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Beautiful', r_ui=None, est=3.4040668442904125, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Trouble', r_ui=None, est=3.3165904072093917, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Everything', r_ui=None, est=3.09403897009388, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Forever Not Yours', r_ui=None, est=2.5702005730659025, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Drive', r_ui=None, est=3.7698140529794992, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="It'S My Life", r_ui=None, est=3.007334033459097, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='All Out Of Love', r_ui=None, est=2.4899713467048707, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Hanging By A Moment', r_ui=None, est=2.7449856733524354, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Stars', r_ui=None, est=2.9614772365488697, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Fly Away', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Underwater Love', r_ui=None, est=2.751216628007459, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='You And Me', r_ui=None, est=3.397708843104258, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Why So Blue', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Where Is The Girl', r_ui=None, est=4.676300578034682, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Phantasmagoria In Two', r_ui=None, est=3.9942196531791914, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Rajaz', r_ui=None, est=2.3294797687861277, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Sailing Ships', r_ui=None, est=2.248554913294797, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="Where'S The Girl? (Reprise)", r_ui=None, est=2.248554913294797, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Soldier Of Fortune', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid="I'Ll Be Seeing You", r_ui=None, est=2.2254335260115607, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Tears', r_ui=None, est=2.3178888115485883, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Crosses', r_ui=None, est=3.268024524295501, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Last Supper', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Overture', r_ui=None, est=3.3110901172726104, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Gethsemane (I Only Want To Say)', r_ui=None, est=1.9017341040462428, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Hunting High And Low', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Here I Go Again', r_ui=None, est=1.832369942196532, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Goodnight Moon', r_ui=None, est=1.7514450867052025, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Heaven On Their Minds', r_ui=None, est=1.7283236994219653, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Let Me Kiss You', r_ui=None, est=2.4631434076520784, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Ljeto Pocinje S Nama', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="She'S Lost Control", r_ui=None, est=4.086326282920663, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Jedan Zivot', r_ui=None, est=4.12536443148688, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Lounge Act', r_ui=None, est=2.795918367346939, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Bubblegum Boy', r_ui=None, est=2.294460641399417, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Lollobrigida Incorporated', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Wonderwall', r_ui=None, est=3.2339180267036514, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Pillow Boy, Baby Girl', r_ui=None, est=1.8862973760932944, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Katarina Velika', r_ui=None, est=1.8746355685131195, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Haunted', r_ui=None, est=2.7718207384091436, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Provincijalka', r_ui=None, est=1.6064139941690962, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Vrati Se', r_ui=None, est=1.5364431486880463, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Straight Edge', r_ui=None, est=1.5247813411078717, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Mona The Girlsbuster', r_ui=None, est=1.489795918367347, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Just Wanna Be Rat', r_ui=None, est=1.489795918367347, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Kraj (Final)', r_ui=None, est=1.4781341107871722, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Miss Right And Mr Wrong', r_ui=None, est=1.466472303206997, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Volim Te', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid="Cut'N'Paste", r_ui=None, est=1.4431486880466473, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Shempi', r_ui=None, est=5, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Nostrand', r_ui=None, est=4.343108504398828, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Falcon Jab', r_ui=None, est=4.237536656891495, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Wildcat', r_ui=None, est=3.1177075861985486, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Mirando', r_ui=None, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'}),
#  Prediction(uid='user_000829', iid='Pompeii Am Götterdämmerung', r_ui=None, est=2.8533724340175954, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Wildcat (E*Vax Remix)', r_ui=None, est=3.3698924731182798, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Hunted By A Freak', r_ui=None, est=3.873900293255132, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Lex', r_ui=None, est=1.4705882352941175, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='A.M. 180', r_ui=None, est=2.489736070381232, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Dr. Groxtronix & Lil Kül Lol', r_ui=None, est=2.466275659824047, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Harder, Better, Faster, Stronger', r_ui=None, est=3.5129517579497165, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Glasgow Mega-Snake', r_ui=None, est=2.3841642228739004, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Friend Is A Four Letter Word', r_ui=None, est=2.2785923753665687, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Love Will Tear Us Apart', r_ui=None, est=3.696621004462956, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='I Will Survive', r_ui=None, est=2.231671554252199, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Veridis Quo', r_ui=None, est=2.231671554252199, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Wheels', r_ui=None, est=2.1495601173020527, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='J. Smith', r_ui=None, est=4.294117647058823, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Somewhere Else', r_ui=None, est=4.141176470588235, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='My Eyes', r_ui=None, est=3.7789915966386554, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Closer', r_ui=None, est=3.1898157222576495, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Viva La Vida', r_ui=None, est=3.3673921852062243, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='One Day Like This', r_ui=None, est=3.8117647058823527, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='In The Morning', r_ui=None, est=3.217345399698341, details={'actual_k': 0, 'was_impossible': False}),
#  ...]

# %%
len(predictions)
# Out:
# 14740

# %%
# #Ordenamos de mayor a menor estimación de relevancia
predictions.sort(key=lambda x : x.est, reverse=True)
#Se convierte a dataframe
labels = ['track_name', 'estimation']
df_predictions = pd.DataFrame.from_records(list(map(lambda x: (x.iid, x.est) , predictions)), columns=labels)
 
# Lo unimos con el dataframe de películas
# df_predictions = df_predictions.merge(items[['track_name','movie title','IMDb URL ']], how='left', on='movie id')
df_predictions
# Out:
#                           track_name  estimation
# 0                     Wings Of Words         5.0
# 1                          La Paloma         5.0
# 2           Je T'Aime...Moi Non Plus         5.0
# 3                            Disease         5.0
# 4               Love, Sweat And Beer         5.0
# ...                              ...         ...
# 14735                     Noah'S Ark         1.0
# 14736  Now I Know How Morrissey Felt         1.0
# 14737                     Procession         1.0
# 14738                      Rabenwald         1.0
# 14739                       Track  9         1.0
#
# [14740 rows x 2 columns]

# %%
user_predictions = list(filter(lambda x: x[0]=='user_000829',predictions))
user_predictions
# Out:
# [Prediction(uid='user_000829', iid='Live Forever', r_ui=5.0, est=3.363082230722521, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="Rock 'N' Roll Star", r_ui=4.551724137931035, est=4.551724137931035, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Acquiesce', r_ui=4.379310344827586, est=4.379310344827586, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Cigarettes & Alcohol', r_ui=4.1034482758620685, est=2.8390804597701145, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Spread Your Love', r_ui=4.0344827586206895, est=4.031081480855198, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Champagne Supernova', r_ui=4.0, est=3.9962335216572504, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Love Burns', r_ui=3.896551724137931, est=3.896470161477328, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Rifles', r_ui=3.827586206896552, est=3.829267099968639, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="Ain'T No Easy Way", r_ui=3.793103448275862, est=4.105602822323794, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid="Don'T Look Back In Anger", r_ui=3.689655172413793, est=2.620065936024236, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Comfortably Numb', r_ui=3.689655172413793, est=3.697218560710076, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Wish You Were Here', r_ui=3.689655172413793, est=3.6465953293600935, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Shuffle Your Feet', r_ui=3.689655172413793, est=3.689803851941495, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Money', r_ui=3.6206896551724137, est=3.6142754784645237, details={'actual_k': 2, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Gimme Shelter', r_ui=3.586206896551724, est=2.1666666666666665, details={'actual_k': 0, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Weight Of The World', r_ui=3.4482758620689657, est=3.3558769002595477, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Bitter Sweet Symphony', r_ui=3.4482758620689657, est=3.5130616509926855, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='The Masterplan', r_ui=3.3793103448275863, est=3.3793103448275863, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Rock And Roll', r_ui=3.3793103448275863, est=3.3539184952978056, details={'actual_k': 1, 'was_impossible': False}),
#  Prediction(uid='user_000829', iid='Communication Breakdown', r_ui=3.3793103448275863, est=3.1958389427321183, details={'was_impossible': True, 'reason': 'User and/or item is unknown.'})]
